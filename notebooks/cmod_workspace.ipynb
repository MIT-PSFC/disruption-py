# %%
# import sys
# sys.path.insert(1, '../src')
from MDSplus import *
from disruption_py import database, plasma
import matplotlib.pyplot as plt
import importlib
import pandas as pd
from IPython.display import display
importlib.reload(database)
importlib.reload(plasma)
# Out:
# <module 'disruption_py.plasma' from '/home/hmturner/Documents/disruption-warning-db-workflow/disruption_py/plasma.py'>

# %%
print(__package__)
# Out:
# None

# %%
test_handler = database.create_cmod_handler()
true_shot = test_handler.get_shot(1150922001)
true_shot.data.head()
# Out:
# /home/hmturner/Documents/disruption-warning-db-workflow/disruption_py/data/sqljdbc4.jar
# /home/hmturner/Documents/disruption-warning-db-workflow/notebooks
# /home/hmturner/.local/lib/python3.8/site-packages/pandas/io/sql.py:762: UserWarning: pandas only support SQLAlchemy connectable(engine/connection) ordatabase string URI or sqlite3 DBAPI2 connectionother DBAPI2 objects are not tested, please consider using SQLAlchemy
#   warnings.warn(
#    dbkey        shot  time time_until_disrupt      ip_error        dip_dt  \
# 0  21457  1150922001  0.06               None           NaN  6.260080e+06
# 1  21458  1150922001  0.08               None           NaN  5.876882e+06
# 2  21459  1150922001  0.10               None  38626.742188  1.954519e+06
# 3  21460  1150922001  0.12               None  71370.562500  1.568255e+06
# 4  21461  1150922001  0.14               None  65597.859375  1.568518e+06
#
#      beta_p    beta_n        li  n_equal_1_normalized  ...  Te_peaking  \
# ...

# %%
shot = plasma.CmodShot('cmod', 1150922001)
shot.data.head()
# Out:
# []
#    times commit_hash  time_until_disrupt             ip        dip_dt  \
# 0   0.06  b'4c3dc07'               99.94  362075.570106  6.260080e+06
# 1   0.08  b'4c3dc07'               99.92  482791.882656  5.876708e+06
# 2   0.10  b'4c3dc07'               99.90  588626.742084  1.954519e+06
# 3   0.12  b'4c3dc07'               99.88  656106.812500  1.568255e+06
# 4   0.14  b'4c3dc07'               99.86  685070.421658  1.568469e+06
#
#    dip_smoothed  dipprog_dt      ip_error  z_error  zcur  ...  \
# 0  6.049903e+06         NaN           NaN      NaN   NaN  ...
# 1  6.013503e+06         NaN           NaN      NaN   NaN  ...
# 2  4.660650e+06         NaN           NaN      NaN   NaN  ...
# 3  1.066818e+06  1999999.75  66106.825845      NaN   NaN  ...
# 4  1.530047e+06  1999999.75  55070.433447      NaN   NaN  ...
#
#    n_equal_1_normalized  Te_width  ne_peaking  Te_peaking  pressure_peaking  \
# 0              0.001876       NaN         NaN         NaN               NaN
# ...

# %%
ignore_cols = ['Prad_peaking_CVA','commit_hash','time','dbkey','shot','H98','v_edge','p_rad_slow',
'p_oh_slow','power_supply_railed','v_loop_efit','r_dd','intentional_disruption','Te_width_ECE',
'Te_peaking_ECE','SXR_peaking','H_alpha']
for col in true_shot.data.columns:
    if 'Mirnov' in col:
        continue
    if col in ignore_cols:
        continue
    print(col)
    plt.figure()
    plt.title(col)
    plt.plot(true_shot.data['time'], true_shot.data[col], label='database')
    plt.plot(shot.data['times'], shot.data[col],'--',label='library')
    plt.legend()
# Out:
# time_until_disrupt
# ip_error
# dip_dt
# beta_p
# beta_n
# li
# n_equal_1_normalized
# z_error
# v_z
# z_times_v_z
# kappa
# /usr/lib/python3/dist-packages/matplotlib/cbook/__init__.py:1402: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   ndim = x[:, None].ndim
# /usr/lib/python3/dist-packages/matplotlib/axes/_base.py:276: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   x = x[:, np.newaxis]
# /usr/lib/python3/dist-packages/matplotlib/axes/_base.py:278: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   y = y[:, np.newaxis]
# pressure_peaking
# q0
# qstar
# q95
# v_0
# v_mid
# ...
