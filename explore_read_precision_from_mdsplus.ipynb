# %% [markdown]
# Use virtual environment's python interpreter to run the notebook

# %%
import pandas as pd

# Replace 'your_file.csv' with the path to your CSV file
df = pd.read_csv('output_cast_float64.txt', header=None)

# %%
df.rename(columns={0: 'tree_name', 1: 'MDSplus cast', 2: 'is ndarray', 3: 'numpy cast'}, inplace=True)

# %%
pd.DataFrame(df.groupby('tree_name')['MDSplus cast'].value_counts())
# Out:
#                                                                                  count
# tree_name                               MDSplus cast
# .ece.gpc_results.rad:r1                 <class 'MDSplus.mdsarray.Float32Array'>    206
# .ece.gpc_results.rad:r2                 <class 'MDSplus.mdsarray.Float32Array'>    206
# .ece.gpc_results.rad:r3                 <class 'MDSplus.mdsarray.Float32Array'>    206
# .ece.gpc_results.rad:r4                 <class 'MDSplus.mdsarray.Float32Array'>    206
# .ece.gpc_results.rad:r5                 <class 'MDSplus.mdsarray.Float32Array'>    206
# .ece.gpc_results.rad:r6                 <class 'MDSplus.mdsarray.Float32Array'>    206
# .ece.gpc_results.rad:r7                 <class 'MDSplus.mdsarray.Float32Array'>    207
# .ece.gpc_results.rad:r8                 <class 'MDSplus.mdsarray.Float32Array'>    207
# .ece.gpc_results.rad:r9                 <class 'MDSplus.mdsarray.Float32Array'>    207
# ...

# %%
pd.DataFrame(df.groupby('tree_name')['MDSplus cast'].value_counts()).to_html()
# Out:
# '<table border="1" class="dataframe">\n  <thead>\n    <tr style="text-align: right;">\n      <th></th>\n      <th></th>\n      <th>count</th>\n    </tr>\n    <tr>\n      <th>tree_name</th>\n      <th>MDSplus cast</th>\n      <th></th>\n    </tr>\n  </thead>\n  <tbody>\n    <tr>\n      <th>.ece.gpc_results.rad:r1</th>\n      <th>&lt;class \'MDSplus.mdsarray.Float32Array\'&gt;</th>\n      <td>206</td>\n    </tr>\n    <tr>\n      <th>.ece.gpc_results.rad:r2</th>\n      <th>&lt;class \'MDSplus.mdsarray.Float32Array\'&gt;</th>\n      <td>206</td>\n    </tr>\n    <tr>\n      <th>.ece.gpc_results.rad:r3</th>\n      <th>&lt;class \'MDSplus.mdsarray.Float32Array\'&gt;</th>\n      <td>206</td>\n    </tr>\n    <tr>\n      <th>.ece.gpc_results.rad:r4</th>\n      <th>&lt;class \'MDSplus.mdsarray.Float32Array\'&gt;</th>\n      <td>206</td>\n    </tr>\n    <tr>\n      <th>.ece.gpc_results.rad:r5</th>\n      <th>&lt;class \'MDSplus.mdsarray.Float32Array\'&gt;</th>\n      <td>206</td>\n    </tr>\n   
# ...

# %%
pd.DataFrame(df.groupby('tree_name')['numpy cast'].value_counts())
# Out:
#                                                                  count
# tree_name                               numpy cast
# .ece.gpc_results.rad:r1                 <class 'numpy.float32'>    206
# .ece.gpc_results.rad:r2                 <class 'numpy.float32'>    206
# .ece.gpc_results.rad:r3                 <class 'numpy.float32'>    206
# .ece.gpc_results.rad:r4                 <class 'numpy.float32'>    206
# .ece.gpc_results.rad:r5                 <class 'numpy.float32'>    206
# .ece.gpc_results.rad:r6                 <class 'numpy.float32'>    206
# .ece.gpc_results.rad:r7                 <class 'numpy.float32'>    207
# .ece.gpc_results.rad:r8                 <class 'numpy.float32'>    207
# .ece.gpc_results.rad:r9                 <class 'numpy.float32'>    207
# .ece.gpc_results.te:te1                 <class 'numpy.float32'>    207
# .ece.gpc_results.te:te2                 <class 'numpy.float32'>    207
# ...
